# %%
#import json
#f = open('history.json', 'r')
#history = json.load(f)
#f.close()
import pickle
history = pickle.load(open('./trainHistoryDict', "rb"))

# %%
history.keys()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

plt.plot(history["accuracy"], label="acc", ls="-", marker="o")
plt.plot(history["val_accuracy"], label="val_acc", ls="-", marker="x")
plt.ylabel("accuracy")
plt.xlabel("epoch")
plt.legend(loc="best")
# plt.show()
